# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
train = pd.read_csv('E:/kaggle/houseprice/data/Mtrain.csv')
train.describe()
# Out:
#         MSSubClass  LotFrontage      LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.217043     0.167527     0.043080     0.566591     0.571918
# std       0.248827     0.075431     0.046653     0.153666     0.139100
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.133562     0.029229     0.444444     0.500000
# 50%       0.176471     0.165431     0.038227     0.555556     0.500000
# 75%       0.294118     0.198630     0.048150     0.666667     0.625000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.719332      0.581096     0.064448     0.078604     0.030504
# std       0.218862      0.344090     0.112957     0.080811     0.105714
# ...

# %%
train['MSSubClass'].plot.hist()

# %%
train['LotFrontage'].plot.hist()

# %%
train['LotArea'].plot.hist();

# %%
train['OverallQual'].plot.hist()

# %%
train['YearBuilt'].plot.hist()

# %%
import seaborn as sns
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
import numpy as np
plt.scatter(train['LotArea'][train['LotArea']<0.5],train['SalePrice'][train['LotArea']<0.5])
