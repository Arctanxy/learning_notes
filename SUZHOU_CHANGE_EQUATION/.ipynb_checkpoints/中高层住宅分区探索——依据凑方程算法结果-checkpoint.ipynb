# %% [markdown]
# # 将小区数据重新细分

# %% [markdown]
# ## 中高层小区，原分级8-18

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
df = pd.read_excel(r"H:\learning_notes\SUZHOU_CHANGE_EQUATION\中高层住宅系数计算结果.xlsx")
df.head(20)
# Out:
#      城市 行政区域     类型                     小区名称            地址  所在楼层  总楼层     面积  \
# 0   宿州市  埇桥区  中高层住宅       三里洋房 2.4.6#（8）有地下室  迎宾大道与淮海南路交叉口     2    8  98.30
# 1   宿州市  埇桥区  中高层住宅       三里洋房 2.4.6#（8）有地下室  迎宾大道与淮海南路交叉口     3    8  99.17
# 2   宿州市  埇桥区  中高层住宅       三里洋房 2.4.6#（8）有地下室  迎宾大道与淮海南路交叉口     4    8  98.30
# 3   宿州市  埇桥区  中高层住宅       三里洋房 2.4.6#（8）有地下室  迎宾大道与淮海南路交叉口     5    8  99.46
# 4   宿州市  埇桥区  中高层住宅       三里洋房 2.4.6#（8）有地下室  迎宾大道与淮海南路交叉口     6    8  99.17
# 5   宿州市  埇桥区  中高层住宅       三里洋房 2.4.6#（8）有地下室  迎宾大道与淮海南路交叉口     7    8  98.30
# 6   宿州市  埇桥区  中高层住宅       三里洋房 2.4.6#（8）有地下室  迎宾大道与淮海南路交叉口     8    8  99.46
# 7   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     2    8  98.30
# 8   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     3    8  99.17
# 9   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     4    8  98.30
# 10  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     5    8  99.46
# 11  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     6    8  99.17
# 12  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     7    8  98.30
# 13  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     8    8  99.46
# 14  宿州市  埇桥区  中高层住宅    三里洋房 9.11#（11）有院 有地下室  迎宾大道与淮海南路交叉口     2   11  98.30
# 15  宿州市  埇桥区  中高层住宅    三里洋房 9.11#（11）有院 有地下室  迎宾大道与淮海南路交叉口     3   11  99.17
# 16  宿州市  埇桥区  中高层住宅    三里洋房 9.11#（11）有院 有地下室  迎宾大道与淮海南路交叉口     4   11  98.30
# 17  宿州市  埇桥区  中高层住宅    三里洋房 9.11#（11）有院 有地下室  迎宾大道与淮海南路交叉口     5   11  99.46
# 18  宿州市  埇桥区  中高层住宅    三里洋房 9.11#（11）有院 有地下室  迎宾大道与淮海南路交叉口     6   11  99.17
# 19  宿州市  埇桥区  中高层住宅    三里洋房 9.11#（11）有院 有地下室  迎宾大道与淮海南路交叉口     7   11  98.30
#
#          结构  建筑年代                        ...                            单价  \
# 0   钢筋混凝土结构  2013                        ...                          4900
# 1   钢筋混凝土结构  2013                        ...                          4920
# 2   钢筋混凝土结构  2013                        ...                          4940
# 3   钢筋混凝土结构  2013                        ...                          4960
# 4   钢筋混凝土结构  2013                        ...                          4980
# 5   钢筋混凝土结构  2013                        ...                          4960
# 6   钢筋混凝土结构  2013                        ...                          4900
# 7   钢筋混凝土结构  2013                        ...                          4800
# 8   钢筋混凝土结构  2013                        ...                          4820
# 9   钢筋混凝土结构  2013                        ...                          4840
# 10  钢筋混凝土结构  2013                        ...                          4860
# 11  钢筋混凝土结构  2013                        ...                          4880
# 12  钢筋混凝土结构  2013                        ...                          4860
# 13  钢筋混凝土结构  2013                        ...                          4800
# 14  钢筋混凝土结构  2013                        ...                          4820
# 15  钢筋混凝土结构  2013                        ...                          4840
# 16  钢筋混凝土结构  2013                        ...                          4860
# 17  钢筋混凝土结构  2013                        ...                          4880
# 18  钢筋混凝土结构  2013                        ...                          4900
# 19  钢筋混凝土结构  2013                        ...                          4920
#
#    朝向系数 成新系数  结构系数  面积系数  装修系数     ratio         评估价格         xishu  \
# 0   100  103   102   100    98  0.250000  4888.571581  18660.369914
# 1   100  103   102   100    98  0.375000  4928.571562  18813.055505
# 2   100  103   102   100    98  0.500000  4954.285836  18911.210531
# 3   100  103   102   100    98  0.625000  4965.714403  18954.834990
# 4   100  103   102   100    98  0.750000  4962.857264  18943.928882
# 5   100  103   102   100    98  0.875000  4945.714417  18878.492209
# 6   100  103   102   100    98  1.000000  4914.285863  18758.524969
# 7   100  103   102   100    98  0.250000  4788.571563  57378.699594
# 8   100  103   102   100    98  0.375000  4828.571567  57857.996650
# 9   100  103   102   100    98  0.500000  4854.285856  58166.116181
# 10  100  103   102   100    98  0.625000  4865.714428  58303.058189
# 11  100  103   102   100    98  0.750000  4862.857284  58268.822672
# 12  100  103   102   100    98  0.875000  4845.714423  58063.409630
# 13  100  103   102   100    98  1.000000  4814.285846  57686.819065
# 14  100  103   102   100    98  0.181818  4795.454041    493.557611
# 15  100  103   102   100    98  0.272727  4843.272219    498.479153
# 16  100  103   102   100    98  0.363636  4879.120702    502.168749
# 17  100  103   102   100    98  0.454545  4902.999490    504.626401
# 18  100  103   102   100    98  0.545455  4914.908581    505.852109
# 19  100  103   102   100    98  0.636364  4914.847977    505.845871
#
#                                              equation
# 0   [ -1744.97812075   2312.0960576   18191.40703203]
# 1   [ -1744.97812075   2312.0960576   18191.40703203]
# 2   [ -1744.97812075   2312.0960576   18191.40703203]
# 3   [ -1744.97812075   2312.0960576   18191.40703203]
# 4   [ -1744.97812075   2312.0960576   18191.40703203]
# 5   [ -1744.97812075   2312.0960576   18191.40703203]
# 6   [ -1744.97812075   2312.0960576   18191.40703203]
# 7   [ -5477.68077805   7257.92693353  55906.57290917]
# 8   [ -5477.68077805   7257.92693353  55906.57290917]
# 9   [ -5477.68077805   7257.92693353  55906.57290917]
# 10  [ -5477.68077805   7257.92693353  55906.57290917]
# 11  [ -5477.68077805   7257.92693353  55906.57290917]
# 12  [ -5477.68077805   7257.92693353  55906.57290917]
# 13  [ -5477.68077805   7257.92693353  55906.57290917]
# 14        [ -74.53265705   88.01543694  480.01869397]
# 15        [ -74.53265705   88.01543694  480.01869397]
# 16        [ -74.53265705   88.01543694  480.01869397]
# 17        [ -74.53265705   88.01543694  480.01869397]
# 18        [ -74.53265705   88.01543694  480.01869397]
# 19        [ -74.53265705   88.01543694  480.01869397]
#
# [20 rows x 23 columns]

# %% [markdown]
# ## 先按小区计算评估价格，判断楼层系数归一化对评估价格的影响
#
# 先挑选一个小区，以三里洋房为例

# %%
data = df[(df['小区名称'] == '三里洋房 3.5#  （8）一层门面 有地下室')&(df['类型'] == '中高层住宅')]
data
# Out:
#      城市 行政区域     类型                     小区名称            地址  所在楼层  总楼层     面积  \
# 7   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     2    8  98.30
# 8   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     3    8  99.17
# 9   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     4    8  98.30
# 10  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     5    8  99.46
# 11  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     6    8  99.17
# 12  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     7    8  98.30
# 13  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     8    8  99.46
#
#          结构  建筑年代                        ...                            单价  \
# 7   钢筋混凝土结构  2013                        ...                          4800
# 8   钢筋混凝土结构  2013                        ...                          4820
# 9   钢筋混凝土结构  2013                        ...                          4840
# 10  钢筋混凝土结构  2013                        ...                          4860
# 11  钢筋混凝土结构  2013                        ...                          4880
# 12  钢筋混凝土结构  2013                        ...                          4860
# 13  钢筋混凝土结构  2013                        ...                          4800
#
#    朝向系数 成新系数  结构系数  面积系数  装修系数  ratio         评估价格         xishu  \
# 7   100  103   102   100    98  0.250  4788.571563  57378.699594
# 8   100  103   102   100    98  0.375  4828.571567  57857.996650
# 9   100  103   102   100    98  0.500  4854.285856  58166.116181
# 10  100  103   102   100    98  0.625  4865.714428  58303.058189
# 11  100  103   102   100    98  0.750  4862.857284  58268.822672
# 12  100  103   102   100    98  0.875  4845.714423  58063.409630
# 13  100  103   102   100    98  1.000  4814.285846  57686.819065
#
#                                              equation
# 7   [ -5477.68077805   7257.92693353  55906.57290917]
# 8   [ -5477.68077805   7257.92693353  55906.57290917]
# 9   [ -5477.68077805   7257.92693353  55906.57290917]
# 10  [ -5477.68077805   7257.92693353  55906.57290917]
# 11  [ -5477.68077805   7257.92693353  55906.57290917]
# 12  [ -5477.68077805   7257.92693353  55906.57290917]
# 13  [ -5477.68077805   7257.92693353  55906.57290917]
#
# [7 rows x 23 columns]

# %% [markdown]
# ### 未归一化之前

# %%
data['xishu'] = data['xishu']*100/(data['xishu'].mean())
data['比准价格'] = data['单价']*1e12/(data['朝向系数']*data['成新系数']*data['结构系数']*data['面积系数']*data['装修系数']*data['xishu'])
data['基准价格'] = data['比准价格'].mean()
data['评估价格'] = data['基准价格']*(data['朝向系数']*data['成新系数']*data['结构系数']*data['面积系数']*data['装修系数']*data['xishu'])/1e12
fig = plt.figure(figsize=(10,6))
plt.plot(data['单价'],color = 'r')
plt.plot(data['评估价格'],color = 'g')

# %%
data
# Out:
#      城市 行政区域     类型                     小区名称            地址  所在楼层  总楼层     面积  \
# 7   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     2    8  98.30
# 8   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     3    8  99.17
# 9   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     4    8  98.30
# 10  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     5    8  99.46
# 11  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     6    8  99.17
# 12  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     7    8  98.30
# 13  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     8    8  99.46
#
#          结构  建筑年代     ...      成新系数 结构系数 面积系数  装修系数  ratio         评估价格  \
# 7   钢筋混凝土结构  2013     ...       103  102  100    98  0.250  4788.571563
# 8   钢筋混凝土结构  2013     ...       103  102  100    98  0.375  4828.571567
# 9   钢筋混凝土结构  2013     ...       103  102  100    98  0.500  4854.285856
# 10  钢筋混凝土结构  2013     ...       103  102  100    98  0.625  4865.714428
# 11  钢筋混凝土结构  2013     ...       103  102  100    98  0.750  4862.857284
# 12  钢筋混凝土结构  2013     ...       103  102  100    98  0.875  4845.714423
# 13  钢筋混凝土结构  2013     ...       103  102  100    98  1.000  4814.285846
#
#          xishu                                           equation  \
# 7    98.995865  [ -5477.68077805   7257.92693353  55906.57290917]
# 8    99.822800  [ -5477.68077805   7257.92693353  55906.57290917]
# 9   100.354401  [ -5477.68077805   7257.92693353  55906.57290917]
# 10  100.590668  [ -5477.68077805   7257.92693353  55906.57290917]
# 11  100.531601  [ -5477.68077805   7257.92693353  55906.57290917]
# 12  100.177200  [ -5477.68077805   7257.92693353  55906.57290917]
# 13   99.527466  [ -5477.68077805   7257.92693353  55906.57290917]
#
#            比准价格         基准价格
# 7   4709.347189  4698.134589
# 8   4689.794570  4698.134589
# 9   4684.308276  4698.134589
# 10  4692.616971  4698.134589
# 11  4714.696619  4698.134589
# 12  4711.985088  4698.134589
# 13  4684.193409  4698.134589
#
# [7 rows x 25 columns]

# %% [markdown]
# ### 归一化之后

# %%
data['xishu'] = data['xishu']*100/(data['xishu'].mean())
data['比准价格'] = data['单价']*1e12/(data['朝向系数']*data['成新系数']*data['结构系数']*data['面积系数']*data['装修系数']*data['xishu'])
data['基准价格'] = data['比准价格'].mean()
data['评估价格'] = data['基准价格']*(data['朝向系数']*data['成新系数']*data['结构系数']*data['面积系数']*data['装修系数']*data['xishu'])/1e12
fig = plt.figure(figsize=(10,6))
plt.plot(data['单价'],color = 'r')
plt.plot(data['评估价格'],color = 'g')

# %% [markdown]
# 由此可以看出，归一化之后的评估价格不会有变化，所以可以放心地对系数进行归一化

# %%
data
# Out:
#      城市 行政区域     类型                     小区名称            地址  所在楼层  总楼层     面积  \
# 7   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     2    8  98.30
# 8   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     3    8  99.17
# 9   宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     4    8  98.30
# 10  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     5    8  99.46
# 11  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     6    8  99.17
# 12  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     7    8  98.30
# 13  宿州市  埇桥区  中高层住宅  三里洋房 3.5#  （8）一层门面 有地下室  迎宾大道与淮海南路交叉口     8    8  99.46
#
#          结构  建筑年代     ...      成新系数 结构系数 面积系数  装修系数  ratio         评估价格  \
# 7   钢筋混凝土结构  2013     ...       103  102  100    98  0.250  4788.571563
# 8   钢筋混凝土结构  2013     ...       103  102  100    98  0.375  4828.571567
# 9   钢筋混凝土结构  2013     ...       103  102  100    98  0.500  4854.285856
# 10  钢筋混凝土结构  2013     ...       103  102  100    98  0.625  4865.714428
# 11  钢筋混凝土结构  2013     ...       103  102  100    98  0.750  4862.857284
# 12  钢筋混凝土结构  2013     ...       103  102  100    98  0.875  4845.714423
# 13  钢筋混凝土结构  2013     ...       103  102  100    98  1.000  4814.285846
#
#          xishu                                           equation  \
# 7    98.995865  [ -5477.68077805   7257.92693353  55906.57290917]
# 8    99.822800  [ -5477.68077805   7257.92693353  55906.57290917]
# 9   100.354401  [ -5477.68077805   7257.92693353  55906.57290917]
# 10  100.590668  [ -5477.68077805   7257.92693353  55906.57290917]
# 11  100.531601  [ -5477.68077805   7257.92693353  55906.57290917]
# 12  100.177200  [ -5477.68077805   7257.92693353  55906.57290917]
# 13   99.527466  [ -5477.68077805   7257.92693353  55906.57290917]
#
#            比准价格         基准价格
# 7   4709.347189  4698.134589
# 8   4689.794570  4698.134589
# 9   4684.308276  4698.134589
# 10  4692.616971  4698.134589
# 11  4714.696619  4698.134589
# 12  4711.985088  4698.134589
# 13  4684.193409  4698.134589
#
# [7 rows x 25 columns]

# %% [markdown]
# ## 细分探索

# %%
def divide_into(floor =8):
    d1 = df[df['总楼层'] == floor]
    for name,group in d1.groupby('小区名称'):
        group['xishu'] = 100 * group['xishu']/group['xishu'].mean()
        plt.plot(group['所在楼层']/group['总楼层'],group['xishu'])

# %%
plt.figure(figsize=(10,5))
divide_into(8)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 9)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 10)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 11)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 12)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 13)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 14)

# %%
plt.figure(figsize=(10,5))
for i in range(10,15):
    divide_into(floor = i)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 15)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 17)

# %%
plt.figure(figsize=(10,5))
divide_into(floor = 18)

# %%
plt.figure(figsize=(10,5))
for i in range(15,19):
    divide_into(floor=i)

# %%
plt.figure(figsize=(10,5))
for i in range(8,19):
    divide_into(floor=i)

# %%
# 15-18 为一组

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['单价'],df['单价'],color = 'r')
plt.scatter(df['单价'],df['评估价格'],color = 'g')
